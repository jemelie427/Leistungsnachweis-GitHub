# %% [markdown]
# # Grosse Veränderungen der Lebenserwartung
#
# Gruppe: Karin Moser, Valeria Schönyan, Jessica Schmid, Simon Mettler
#
# Fragen
#     - Welche Länder hatten in den letzten 10 Jahre die grösste Zunahme/Abnahme der Sterblichkeit bei Säuglingen (< 1 Jahr)?
#     - Was sind die Gründe dafür?
#
# Quelle:
#     - https://ourworldindata.org/grapher/infant-mortality.metadata.json?v=1&csvType=full&useColumnShortNames=true
